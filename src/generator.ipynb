# %% [markdown]
# Name: Noor Buchi

# %%
# !pip install aitextgen
# Out:
# Collecting aitextgen
#   Downloading aitextgen-0.5.2.tar.gz (572 kB)
#      |████████████████████████████████| 572 kB 10.8 MB/s
# Collecting transformers>=4.5.1
#   Downloading transformers-4.12.3-py3-none-any.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 73.5 MB/s
# Collecting fire>=0.3.0
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 5.3 MB/s
# Collecting pytorch-lightning>=1.3.1
#   Downloading pytorch_lightning-1.5.0-py3-none-any.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 78.7 MB/s
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from aitextgen) (1.9.0+cu111)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire>=0.3.0->aitextgen) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire>=0.3.0->aitextgen) (1.1.0)
# Collecting future>=0.17.1
#   Downloading future-0.18.2.tar.gz (829 kB)
#      |████████████████████████████████| 829 kB 79.5 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.3.1->aitextgen) (3.7.4.3)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.3.1->aitextgen) (21.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.3.1->aitextgen) (1.19.5)
# Collecting PyYAML>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 67.5 MB/s
# Collecting torchmetrics>=0.4.1
#   Downloading torchmetrics-0.6.0-py3-none-any.whl (329 kB)
#      |████████████████████████████████| 329 kB 72.4 MB/s
# Collecting pyDeprecate==0.3.1
#   Downloading pyDeprecate-0.3.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.3.1->aitextgen) (4.62.3)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.3.1->aitextgen) (2.6.0)
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading fsspec-2021.10.1-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 73.3 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.3.1->aitextgen) (2.23.0)
# Collecting aiohttp
#   Downloading aiohttp-3.8.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 68.1 MB/s
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning>=1.3.1->aitextgen) (2.4.7)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (0.37.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (1.35.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (0.12.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (1.8.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (3.17.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (1.0.1)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (1.41.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (57.4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (4.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.3.1->aitextgen) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.3.1->aitextgen) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.3.1->aitextgen) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.3.1->aitextgen) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (3.1.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=4.5.1->aitextgen) (3.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=4.5.1->aitextgen) (2019.12.20)
# Collecting sacremoses
#   Downloading sacremoses-0.0.46-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 67.6 MB/s
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3 MB)
#      |████████████████████████████████| 3.3 MB 67.8 MB/s
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.1.0-py3-none-any.whl (59 kB)
#      |████████████████████████████████| 59 kB 6.8 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.3.1->aitextgen) (2.0.7)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (160 kB)
#      |████████████████████████████████| 160 kB 67.3 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 66.7 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.3.1->aitextgen) (21.2.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.2.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (192 kB)
#      |████████████████████████████████| 192 kB 70.8 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.0-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard>=2.2.0->pytorch-lightning>=1.3.1->aitextgen) (3.6.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.5.1->aitextgen) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=4.5.1->aitextgen) (7.1.2)
# Building wheels for collected packages: aitextgen, fire, future
#   Building wheel for aitextgen (setup.py) ... done
#   Created wheel for aitextgen: filename=aitextgen-0.5.2-py3-none-any.whl size=575905 sha256=bf79aff8677043bd632c570880f4241fa4de52870d14c6d5655a9de2ac039e5b
#   Stored in directory: /root/.cache/pip/wheels/83/e2/74/46c887b0989a51a7acee0c09551a3ae9d34b939fb4bea404a0
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=d2c6f8a84e0fd04dd9abba47106aa7f872bc8b64a2d1de188e0de4084c1b6a2a
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491070 sha256=7701702fb8d6b98a38d63e394fabfce067c7a7ec6555498040de8ed8739cacc0
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
# Successfully built aitextgen fire future
# Installing collected packages: multidict, frozenlist, yarl, asynctest, async-timeout, aiosignal, PyYAML, fsspec, aiohttp, torchmetrics, tokenizers, sacremoses, pyDeprecate, huggingface-hub, future, transformers, pytorch-lightning, fire, aitextgen
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: future
#     Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
# Successfully installed PyYAML-6.0 aiohttp-3.8.0 aiosignal-1.2.0 aitextgen-0.5.2 async-timeout-4.0.0 asynctest-0.13.0 fire-0.4.0 frozenlist-1.2.0 fsspec-2021.10.1 future-0.18.2 huggingface-hub-0.1.0 multidict-5.2.0 pyDeprecate-0.3.1 pytorch-lightning-1.5.0 sacremoses-0.0.46 tokenizers-0.10.3 torchmetrics-0.6.0 transformers-4.12.3 yarl-1.7.2

# %%
from aitextgen.TokenDataset import TokenDataset
from aitextgen.tokenizers import train_tokenizer
from aitextgen.utils import GPT2ConfigCPU
from aitextgen import aitextgen

# The name of file containing the processed text for training
file_name = "processed_data.txt"

# Train a custom BPE Tokenizer on the downloaded text
# This will save one file: `aitextgen.tokenizer.json`, which contains the
# information needed to rebuild the tokenizer.
train_tokenizer(file_name)
tokenizer_file = "aitextgen.tokenizer.json"

# GPT2ConfigCPU is a mini variant of GPT-2 optimized for CPU-training
# e.g. the # of input tokens here is 64 vs. 1024 for base GPT-2.
config = GPT2ConfigCPU()

# Instantiate aitextgen using the created tokenizer and config
ai = aitextgen(tokenizer_file=tokenizer_file, config=config)

# You can build datasets for training by creating TokenDatasets,
# which automatically processes the dataset with the appropriate size.
data = TokenDataset(file_name, tokenizer_file=tokenizer_file, block_size=64)

# Train the model! It will save pytorch_model.bin periodically and after completion to the `trained_model` folder.
# On a 2020 8-core iMac, this took ~25 minutes to run.
ai.train(data, batch_size=8, num_steps=50000, generate_every=5000, save_every=5000)

# Generate text from it!
ai.generate(10, prompt="The movie")

# With your trained model, you can reload the model at any time by
# providing the folder containing the pytorch_model.bin model weights + the config, and providing the tokenizer.
# ai2 = aitextgen(model_folder="trained_model",
#                 tokenizer_file="aitextgen.tokenizer.json")

# ai2.generate(10, prompt="ROMEO:")
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:148: LightningDeprecationWarning: Setting `Trainer(checkpoint_callback=False)` is deprecated in v1.5 and will be removed in v1.7. Please consider using `Trainer(enable_checkpointing=False)`.
#   f"Setting `Trainer(checkpoint_callback={checkpoint_callback})` is deprecated in v1.5 and will "
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:91: LightningDeprecationWarning: Setting `Trainer(progress_bar_refresh_rate=20)` is deprecated in v1.5 and will be removed in v1.7. Please pass `pytorch_lightning.callbacks.progress.TQDMProgressBar` with `refresh_rate` directly to the Trainer's `callbacks` argument instead. Or, to disable the progress bar pass `enable_progress_bar = False` to the Trainer.
#   f"Setting `Trainer(progress_bar_refresh_rate={progress_bar_refresh_rate})` is deprecated in v1.5 and"
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/connectors/callback_connector.py:168: LightningDeprecationWarning: Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed in v1.7. Please set `Trainer(enable_model_summary=False)` instead.
#   "Setting `Trainer(weights_summary=None)` is deprecated in v1.5 and will be removed"
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
#   0%|          | 0/50000 [00:00<?, ?it/s]
# /usr/local/lib/python3.7/dist-packages/pytorch_lightning/trainer/trainer.py:1806: LightningDeprecationWarning: `trainer.progress_bar_dict` is deprecated in v1.5 and will be removed in v1.7. Use `ProgressBarBase.get_metrics` instead.
#   "`trainer.progress_bar_dict` is deprecated in v1.5 and will be removed in v1.7."
# 5,000 steps reached: saving model to /trained_model
# 5,000 steps reached: generating sample texts.
# ==========
#  fortal to be a bridge Antiobot --ax Repance, and as a brilliant computer programmer designed to cat drive a compels to the brreat to the wal with ed.
# Asteatherishe
# ==========
# 10,000 steps reached: saving model to /trained_model
# 10,000 steps reached: generating sample texts.
# ==========
# licants; The centers hliver it's emotions, and a ride Tyrell Corporation as the Gold behavikaopopies Ol-pons, and the galaxy is another handwr
# ==========
# 15,000 steps reached: saving model to /trained_model
# 15,000 steps reached: generating sample texts.
# ==========
#  of an off-buried secret leads computer programmer. As aver and anyone const of the factburdering initial anside world, Hitashes a father desperating as he uninther him in made. Lanning's im
# ==========
# 20,000 steps reached: saving model to /trained_model
# 20,000 steps reached: generating sample texts.
# ==========
#  of apparent suicide of the scientist, but Due the agents: Batoubtfrinity is the three Severalk to hallucinity of battle to destroy the Zion whose replicants - or in theille e
# ==========
# 25,000 steps reached: saving model to /trained_model
# 25,000 steps reached: generating sample texts.
# ==========
#  of a beautiful robot. However, she has an agent to have the fact, esponed with Machine's relened, Alationship with a fulatic and has police for the disterstellar. 3, is a for
# ==========
# 30,000 steps reached: saving model to /trained_model
# 30,000 steps reached: generating sample texts.
# ==========
#  into a passicities, tries to prevent the transferate stek into questions.
# In 202 hibern finds himself. Flynnn, the awer, the ride as a vaster totor of the contin
# ==========
# 35,000 steps reached: saving model to /trained_model
# 35,000 steps reached: generating sample texts.
# ==========
#  to stop Dolores and Rheoboam have an argument. Dolores sees El Lazo stealing the nitroglycerin and she proves to face to a charm boxing true nature humanity's future.
# TheTheTheresa tells
# ==========
# 40,000 steps reached: saving model to /trained_model
# 40,000 steps reached: generating sample texts.
# ==========
# ing once and the One of the father's los to the H. His best friend Jen's Spoonering total experilot, who duried at age fle lazcher. but when those short and bot a st
# ==========
# 45,000 steps reached: saving model to /trained_model
# 45,000 steps reached: generating sample texts.
# ==========
# , an unlikely ally as they attempt to train in an acros man on his way.
# In the future, Smith is to the near future a deadly mission. Sms, a mately man has galaxy is a s
# ==========
# 50,000 steps reached: saving model to /trained_model
# 50,000 steps reached: generating sample texts.
# ==========
# , David is brought it near to get game back to Earth, but but new hallucination get with unrocer, but the seemingly faminfalls key on-offs lineliness is conflicted by a mon
# ==========
# The movie is concerned with patrolling the skies of a showing that his pullarvest scrapy.
# Maeve is floing with Hector and decides to visit Sector 16 dataughter 17 where
# ==========
# The movie is to the latestant that short and control of Delos, changs the breacherous terrain.
# Maeve and decides to visitcover his falls, Ford asking whitess of Arthur finds that his keepested
# ==========
# The movie  to receive involution, but the last real feelings, especially a never pilot and she might, and living to feels that actuet to uncovery and they brough sugment, the num
# ==========
# The movie is invaders, Neo whose to kill 25,000 sentinels are deters. Inst of the Tglavelaveave soldiering the human Rian, asse that was impives: the Protillion
# ==========
# The movie is concernirected on Earth, WALL-E, EVE, love of EVE spially a pleeatedly cap WALL-E falls in love with EVE, a dust stormant on Aurorom, EVE takes a sens preci
# ==========
# The movie oping the near future has invaded the latest monoliths. Skynet smith's believed the nearne will the Emport it's mission. Discover of the mustries uninved bond
# ==========
# The movieions whether it is itself, or the proble has evolutionalf and has moved to or to know.
# Fat Dolores and past named Dolores has recollections of her preventing her prevent of her previous to Ln
# ==========
# The movie is con acceived as subjected. One, sent from the help of the fearless of the fulfess war with the mechanical colppinging over her life, pruth--the life. In the bet
# ==========
# The movie opatible pilots that have their minds interlocked. Years for opping ingue town of park. Harry's where guests causedations.
# The guests predecessor -lots
# ==========
# The movie is conce the year 2001, the Sl he wanted his new he VRTY, then plant good theners. He deming what the demoliscover of his she will take part of his pers' transfect

# %%
import pickle
# saving the model as a pickle file
with open("my_model.pkl", "wb+") as output_file:
  pickle.dump(ai, output_file)

# %%
# get some output
ai.generate(10, prompt="")
# Out:
# , a littletes and he letimeds for the cent than humans ins. In the midsticer distant-tant past, someonyear-old son, a series of a serferredecim Penting a
# ==========
# In this second adventure, Neo learns more about his superheroic able, but the abilities. In the rebel leaderraw Rift of the rebel leadsl for the Mid radle Vaucan and Cleo and
# ==========
# 's plans to destroy the home.
# During the lat hairs a highte galaucor back from his robot before Co phatons of failsingingings sole physical corniploated
# ==========
# ed. Now Jack repairs improophatissibt is the powerful mult of After oceiandening Wallace is shoted to stopping that Theresa Cull for the world. Meanwhile Elsie.
# Maeve continues
# ==========
# . However, it is rided by a seedling mechanical componentsrinely man. Meanwhile, the Man in Black continue a dangerous and Lawrence is rained assumes an important position in Westworld. Dolores arrive at a r
# ==========
# of fights and he uses the unusbands of mysterious Serac. Meanwhile, Dolores reaches tied to Caleb and reveals more love Matrix, a significant woman named Arthuring mades believes possible
# ==========
# and Rheoboam have been ab who is threat to "fect"red means and it's soon real boxing, his only drawn in the val infanteeving evolan croverting that he faminble.
# In the dis
# ==========
# runners, the Death Star plans and also the assistance of an elderly hermitericiy who original da--inant clusive voyage. Jack repairs is not the power stay for the obs
# ==========
# Sard, sent from the real world's larger's most power complete.. Le in and implicated are in has only house abovered with shared by his one, but husbable persons a robot, and more power
# ==========
# . Meanwhile, Charlotte visually intent in the Ghid, but the Gigolo Joegala, and soonic pilot who left trains him to ridd-tent on the people, which is is found a sleep mod
